# %% [markdown]
# <a href="https://colab.research.google.com/github/poppoppulanaresh-max/CAPSTONE-PROJECTS-PYTHON/blob/main/Wind_Energy_Efficiency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/train (1).csv')

# %%
df
# Out:
#                   timestamp  active_power_calculated_by_converter  \
# 0       2021-02-19 20:18:00                            816.636759
# 1       2021-04-27 04:55:00                            419.107829
# 2       2021-01-25 06:26:00                           1303.530558
# 3       2021-10-30 03:47:00                             61.494872
# 4       2021-03-15 00:39:00                            593.514364
# ...                     ...                                   ...
# 909599  2021-04-25 19:12:00                            929.101908
# 909600  2021-02-20 17:37:00                            100.730526
# 909601  2021-10-22 14:18:00                           1120.915965
# 909602  2021-02-08 22:03:00                            123.444564
# 909603  2021-04-09 14:28:00                              4.843147
#
#         active_power_raw  ambient_temperature  generator_speed  \
# 0             834.917206            31.694380      1159.616602
# ...

# %%
df.shape
# Out:
# (909604, 16)

# %%
df.isnull().sum()
# Out:
# timestamp                                 0
# active_power_calculated_by_converter      0
# active_power_raw                          0
# ambient_temperature                       0
# generator_speed                           0
# generator_winding_temp_max                0
# grid_power10min_average                   0
# nc1_inside_temp                           0
# nacelle_temp                              0
# reactice_power_calculated_by_converter    0
# reactive_power                            0
# wind_direction_raw                        0
# wind_speed_raw                            0
# wind_speed_turbulence                     0
# turbine_id                                0
# Target                                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt

# %%
for i in df.columns:
  if (df[i].dtype != "object"):
    plt.boxplot(df[i])
    plt.title(i)
    plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 909604 entries, 0 to 909603
# Data columns (total 16 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   timestamp                               909604 non-null  object
#  1   active_power_calculated_by_converter    909604 non-null  float64
#  2   active_power_raw                        909604 non-null  float64
#  3   ambient_temperature                     909604 non-null  float64
#  4   generator_speed                         909604 non-null  float64
#  5   generator_winding_temp_max              909604 non-null  float64
#  6   grid_power10min_average                 909604 non-null  float64
#  7   nc1_inside_temp                         909604 non-null  float64
#  8   nacelle_temp                            909604 non-null  float64
#  9   reactice_power_calculated_by_converter  909604 non-null  float64
# ...

# %%
df.head()
# Out:
#              timestamp  active_power_calculated_by_converter  \
# 0  2021-02-19 20:18:00                            816.636759
# 1  2021-04-27 04:55:00                            419.107829
# 2  2021-01-25 06:26:00                           1303.530558
# 3  2021-10-30 03:47:00                             61.494872
# 4  2021-03-15 00:39:00                            593.514364
#
#    active_power_raw  ambient_temperature  generator_speed  \
# 0        834.917206            31.694380      1159.616602
# 1        421.050873            12.894948       928.747996
# 2       1337.566142            16.648388      1201.219775
# 3         53.481008            28.388141       769.806122
# 4        611.659108            31.519527      1046.916768
#
#    generator_winding_temp_max  grid_power10min_average  nc1_inside_temp  \
# 0                   65.954214               917.897085        31.881972
# 1                   59.571319               445.554250        32.423705
# ...

# %%
df['timestamp']=pd.to_datetime(df['timestamp'])

# %%
df['turbine_id'].nunique()
# Out:
# 16

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 909604 entries, 0 to 909603
# Data columns (total 16 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   timestamp                               909604 non-null  datetime64[ns]
#  1   active_power_calculated_by_converter    909604 non-null  float64
#  2   active_power_raw                        909604 non-null  float64
#  3   ambient_temperature                     909604 non-null  float64
#  4   generator_speed                         909604 non-null  float64
#  5   generator_winding_temp_max              909604 non-null  float64
#  6   grid_power10min_average                 909604 non-null  float64
#  7   nc1_inside_temp                         909604 non-null  float64
#  8   nacelle_temp                            909604 non-null  float64
#  9   reactice_power_calculated_by_converter  909604 non-null  float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['turbine_id']=le.fit_transform(df['turbine_id'])

# %%
df.head()
# Out:
#             timestamp  active_power_calculated_by_converter  active_power_raw  \
# 0 2021-02-19 20:18:00                            816.636759        834.917206
# 1 2021-04-27 04:55:00                            419.107829        421.050873
# 2 2021-01-25 06:26:00                           1303.530558       1337.566142
# 3 2021-10-30 03:47:00                             61.494872         53.481008
# 4 2021-03-15 00:39:00                            593.514364        611.659108
#
#    ambient_temperature  generator_speed  generator_winding_temp_max  \
# 0            31.694380      1159.616602                   65.954214
# 1            12.894948       928.747996                   59.571319
# 2            16.648388      1201.219775                   61.270498
# 3            28.388141       769.806122                   40.674348
# 4            31.519527      1046.916768                   64.341763
#
#    grid_power10min_average  nc1_inside_temp  nacelle_temp  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 909604 entries, 0 to 909603
# Data columns (total 16 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   timestamp                               909604 non-null  datetime64[ns]
#  1   active_power_calculated_by_converter    909604 non-null  float64
#  2   active_power_raw                        909604 non-null  float64
#  3   ambient_temperature                     909604 non-null  float64
#  4   generator_speed                         909604 non-null  float64
#  5   generator_winding_temp_max              909604 non-null  float64
#  6   grid_power10min_average                 909604 non-null  float64
#  7   nc1_inside_temp                         909604 non-null  float64
#  8   nacelle_temp                            909604 non-null  float64
#  9   reactice_power_calculated_by_converter  909604 non-null  float64
# ...

# %%
df
# Out:
#                  timestamp  active_power_calculated_by_converter  \
# 0      2021-02-19 20:18:00                            816.636759
# 1      2021-04-27 04:55:00                            419.107829
# 2      2021-01-25 06:26:00                           1303.530558
# 3      2021-10-30 03:47:00                             61.494872
# 4      2021-03-15 00:39:00                            593.514364
# ...                    ...                                   ...
# 909599 2021-04-25 19:12:00                            929.101908
# 909600 2021-02-20 17:37:00                            100.730526
# 909601 2021-10-22 14:18:00                           1120.915965
# 909602 2021-02-08 22:03:00                            123.444564
# 909603 2021-04-09 14:28:00                              4.843147
#
#         active_power_raw  ambient_temperature  generator_speed  \
# 0             834.917206            31.694380      1159.616602
# ...

# %%
x = df.drop(columns = ["Target", "timestamp"])

# %%
x
# Out:
#         active_power_calculated_by_converter  active_power_raw  \
# 0                                 816.636759        834.917206
# 1                                 419.107829        421.050873
# 2                                1303.530558       1337.566142
# 3                                  61.494872         53.481008
# 4                                 593.514364        611.659108
# ...                                      ...               ...
# 909599                            929.101908        948.441905
# 909600                            100.730526         88.694599
# 909601                           1120.915965       1165.016907
# 909602                            123.444564        116.066919
# 909603                              4.843147         10.779734
#
#         ambient_temperature  generator_speed  generator_winding_temp_max  \
# 0                 31.694380      1159.616602                   65.954214
# ...

# %%
y = df["Target"]
y
# Out:
# 0         47.582787
# 1         46.070328
# 2         39.989236
# 3         46.056587
# 4         54.346095
#             ...
# 909599    50.768675
# 909600    44.234821
# 909601    46.942486
# 909602    46.392221
# 909603    48.902180
# Name: Target, Length: 909604, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x = sc.fit_transform(x)

# %%
x
# Out:
# array([[ 0.61259769,  0.61625423,  0.76261266, ...,  0.58758169,
#         -0.33962021, -0.77103581],
#        [-0.22497659, -0.24168717, -1.57980742, ..., -0.21237612,
#         -0.57599023,  0.97112267],
#        [ 1.63845944,  1.65824121, -1.11212664, ...,  1.11115266,
#         -0.09321682, -0.98880562],
#        ...,
#        [ 1.2536993 ,  1.30054811,  0.66377317, ...,  1.34334968,
#          0.94271824,  0.53558305],
#        [-0.84792482, -0.87391632,  0.88765591, ..., -0.79430629,
#         -1.27421845,  1.6244321 ],
#        [-1.09781228, -1.09217576, -0.76273021, ..., -1.96063042,
#          0.97984562, -0.98880562]])

# %%
df.shape
# Out:
# (909604, 16)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=29)

# %%
x_train.shape
# Out:
# (636722, 14)

# %%
x_test.shape
# Out:
# (272882, 14)

# %%
# Train the model ->
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Test the Model ->
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([49.38154624, 46.66965182, 44.94274437, ..., 44.62779361,
#        45.51225391, 46.09084609])

# %%
y_test
# Out:
# 111506    49.375624
# 126330    47.008553
# 677185    44.086337
# 681518    58.133279
# 302329    53.041153
#             ...
# 309341    43.924744
# 820224    49.306791
# 325758    45.474917
# 233096    45.213200
# 261404    45.211977
# Name: Target, Length: 272882, dtype: float64

# %%
# Evaluate ->

# %%
from sklearn.metrics import *

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 1.3621718619927772

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 3.81076323369255

# %%
r2_score(y_test, y_pred)
# Out:
# 0.4416035841484621

# %%
# Build a Decision Tree ->

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor()

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = dt.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.6424795050287548

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(random_state=29)
rf_model.fit(x_train, y_train)
y_pred_rf = rf_model.predict(x_test)
r2_score_rf = r2_score(y_test, y_pred_rf)
print(f"R2 score for Random Forest: {r2_score_rf}")
# Out:
# R2 score for Random Forest: 0.8291201091264664

# %%
# PCA
from sklearn.decomposition import PCA

# %%
p = PCA(n_components=0.95)

# %%
pca_data = p.fit_transform(x)

# %%
x.shape
# Out:
# (909604, 14)

# %%
pca_data.shape
# Out:
# (909604, 8)

# %%
# Train Test Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(pca_data, y, test_size=0.3, random_state = 29)

# %%
X_train.shape
# Out:
# (636722, 8)

# %%
X_test.shape
# Out:
# (272882, 8)

# %%
# LR ->
model = LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
Y_pred
# Out:
# array([48.79084716, 46.52949148, 44.6474348 , ..., 44.31908734,
#        46.12745507, 46.11646864])

# %%
Y_test
# Out:
# 111506    49.375624
# 126330    47.008553
# 677185    44.086337
# 681518    58.133279
# 302329    53.041153
#             ...
# 309341    43.924744
# 820224    49.306791
# 325758    45.474917
# 233096    45.213200
# 261404    45.211977
# Name: Target, Length: 272882, dtype: float64

# %%
r2_score(Y_test, Y_pred)
# Out:
# 0.41413679487029254

# %%
# Decision Tree Regressior
dt = DecisionTreeRegressor()

# %%
dt.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor()

# %%
Y_pred = dt.predict(X_test)

# %%
r2_score(Y_test, Y_pred)
# Out:
# 0.4671663830314743
